# %%
import pandas as pd
import numpy as np
import seaborn as sns
from matplotlib import pyplot as plt
import warnings
warnings.simplefilter('ignore')
# %config InlineBackend.figure_formats = ['svg']
#Импорт нужных библиотек

# %%
full_data = pd.read_csv('data/DEAL_by_funnel_road_to_court.csv', sep=';')
#Считывание данных

# %%
full_data['Відповідальний'] = full_data['Відповідальний'].replace('Вікторія', 'Вікторія Урум')
#Внесение Фамилии к сотруднику у которого нету фамилии в системе

approved_columns = ['Відповідальний',
'Контакт',
'Логін та Пароль від електронної пошти для електронного суду', 
'Основний договір складений на суму', 
'Номер Основного договору',
'Заява до господарського суду', 
'Витрати/доходи. Коментар по справі',
'НЕСУДИМОСТІ.СТАТУС. Довідка',
'ФОП. Довідка &quot;№ ___ від __.__.___&quot;',
'Довідка МРЕО. Відповідно до довідки &quot; № ____ від _____, виданої _________&quot;',
'Довідка з МРЕО. Наявність транспортних засобів. &quot;відсутні&quot; / &quot;є, а саме:&quot;',
"Про склад сім'ї. Записати через крапку з комою всіх ДОРОСЛИХ згідно довідки: &quot;(Ким приходиться)____ - ПІБ, ____ року народження, ______ відповідно до паспорту серії ___ №____ виданого ____ від____ &quot; / або &quot;відмовився надавати відомості&quot;"]
approved_data = full_data[approved_columns]
approved_data = approved_data \
.rename(columns={"Про склад сім'ї. Записати через крапку з комою всіх ДОРОСЛИХ згідно довідки: &quot;(Ким приходиться)____ - ПІБ, ____ року народження, ______ відповідно до паспорту серії ___ №____ виданого ____ від____ &quot; / або &quot;відмовився надавати відомості&quot;":"Про склад сім'ї",
                'Довідка з МРЕО. Наявність транспортних засобів. &quot;відсутні&quot; / &quot;є, а саме:&quot;':'Наявність т. з.',
                'Довідка МРЕО. Відповідно до довідки &quot; № ____ від _____, виданої _________&quot;':'Довідка МРЕО',
                'Логін та Пароль від електронної пошти для електронного суду':'Логін та Пароль Ел суд',
                'Основний договір складений на суму':'Сума договору',
                'Номер Основного договору':'Номер договору',
                'Заява до господарського суду':'Господарський суд',
                'НЕСУДИМОСТІ.СТАТУС. Довідка':'Несудимості',
                'ФОП. Довідка &quot;№ ___ від __.__.___&quot;':'ФОП. Довідка'})
#Отбор нужных полей и переменование столбцов

approved_data = approved_data[approved_data['Відповідальний'] \
                                  .isin(['Інгвар','Балінська Валерія','Вікторія Урум','Романчук Андріана','Федорко Вікторія'])]
#Отбор нужных сотрудников

# %%
approved_data.groupby('Відповідальний').agg({'Контакт':'count'}).rename(columns={'Контакт':'Кількість_угод'}).reset_index()
#Количество сделок принявших участие в аналитике в разбивке по юристам.
# Out:
#       Відповідальний  Кількість_угод
# 0             Інгвар             145
# 1  Балінська Валерія             566
# 2      Вікторія Урум             218
# 3  Романчук Андріана              98
# 4   Федорко Вікторія             107

# %%
grouped_filtred_approved_data = approved_data.groupby('Відповідалreset_index)
grouped_filtred_approved_data.apply(lambda x:x.isna().sum())
#Количество НЕ ЗАПОЛНЕННЫХ полей в сделке в разбивке по юристам.
# Out:
#                    Відповідальний  Контакт  Логін та Пароль Ел суд  \
# Відповідальний
# Інгвар                          0        0                      87
# Балінська Валерія               0        0                     534
# Вікторія Урум                   0        0                     165
# Романчук Андріана               0        0                      82
# Федорко Вікторія                0        0                      76
#
#                    Сума договору  Номер договору  Господарський суд  \
# Відповідальний
# Інгвар                         3               5                 80
# Балінська Валерія             14             195                467
# Вікторія Урум                  4               4                123
# Романчук Андріана             12              14                 40
# Федорко Вікторія              10              13                 62
#
#                    Витрати/доходи. Коментар по справі  Несудимості  \
# Відповідальний
# Інгвар                                            143          141
# Балінська Валерія                                 562          551
# Вікторія Урум                                     216          202
# Романчук Андріана                                  96           85
# Федорко Вікторія                                  107          106
#
#                    ФОП. Довідка  Довідка МРЕО  Наявність т. з.  \
# Відповідальний
# Інгвар                       88            87               84
# Балінська Валерія           515           516              526
# Вікторія Урум               143           138              136
# Романчук Андріана            70            52               56
# Федорко Вікторія            106           105              104
#
#                    Про склад сім'ї
# Відповідальний
# Інгвар                          97
# Балінська Валерія              553
# Вікторія Урум                  154
# Романчук Андріана               96
# Федорко Вікторія               106

# %%
final_result_persentage = grouped_filtred_approved_data.apply(lambda x:x.notna().sum()/len(x)*100)
final_result_persentage = final_result_persentage.drop('Відповідальний', axis=1)
final_result_persentage
#Процент ЗАПОЛНЕННЫХ полей в сделке в разбивке по юристам.
# Out:
#                    Контакт  Логін та Пароль Ел суд  Сума договору  \
# Відповідальний
# Інгвар               100.0               40.000000      97.931034
# Балінська Валерія    100.0                5.653710      97.526502
# Вікторія Урум        100.0               24.311927      98.165138
# Романчук Андріана    100.0               16.326531      87.755102
# Федорко Вікторія     100.0               28.971963      90.654206
#
#                    Номер договору  Господарський суд  \
# Відповідальний
# Інгвар                  96.551724          44.827586
# Балінська Валерія       65.547703          17.491166
# Вікторія Урум           98.165138          43.577982
# Романчук Андріана       85.714286          59.183673
# Федорко Вікторія        87.850467          42.056075
#
#                    Витрати/доходи. Коментар по справі  Несудимості  \
# Відповідальний
# Інгвар                                       1.379310     2.758621
# Балінська Валерія                            0.706714     2.650177
# Вікторія Урум                                0.917431     7.339450
# Романчук Андріана                            2.040816    13.265306
# Федорко Вікторія                             0.000000     0.934579
#
#                    ФОП. Довідка  Довідка МРЕО  Наявність т. з.  \
# Відповідальний
# Інгвар                39.310345     40.000000        42.068966
# Балінська Валерія      9.010601      8.833922         7.067138
# Вікторія Урум         34.403670     36.697248        37.614679
# Романчук Андріана     28.571429     46.938776        42.857143
# Федорко Вікторія       0.934579      1.869159         2.803738
#
#                    Про склад сім'ї
# Відповідальний
# Інгвар                   33.103448
# Балінська Валерія         2.296820
# Вікторія Урум            29.357798
# Романчук Андріана         2.040816
# Федорко Вікторія          0.934579

# %%
sns.heatmap(data=final_result_persentage, cmap="RdYlGn", annot=True, fmt=".1f", linewidths=0.5, linecolor='black');

# %%
sns.heatmap(data=final_result_persentage, cmap="RdYlGn", annot=True, fmt=".1f", linewidths=0.5, linecolor='black')
plt.savefig('heatmap_plot.png', dpi=300, bbox_inches='tight')
